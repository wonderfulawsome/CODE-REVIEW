# %% [markdown]
# ### Transfer Learning

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# 사전 학습된 모델 로드 (Imagenet 가중치 사용)
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# 새로운 레이어 추가
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
predictions = Dense(10, activation='softmax')(x)

# 새로운 모델 생성
model = Model(inputs=base_model.input, outputs=predictions)

# 모든 레이어 학습 가능하도록 설정
for layer in base_model.layers:
    layer.trainable = True

#FC Layer와 Convolution Layer의 다른 learning rate 설정
optimizer = Adam(learning_rate=1e-4)
optimizer_fine_tune = Adam(learning_rate=1e-5)

#모델 컴파일
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# 데이터셋 준비 (CIFAR-10 예시)
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = tf.image.resize(x_train, (224, 224)) / 255.0
x_test = tf.image.resize(x_test, (224, 224)) / 255.0

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# 모델 학습
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    epochs=10,
    batch_size=32
)

# %% [markdown]
# ### Knowledge Distillation

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
import numpy as np

# Teacher 모델 정의 (복잡한 모델)
teacher_model = Sequential([
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

# Teacher 모델 컴파일 및 학습
teacher_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# MNIST 데이터 로드 및 전처리
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
x_train = np.expand_dims(x_train, -1)  # 채널 추가
x_test = np.expand_dims(x_test, -1)
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Teacher 모델 학습
teacher_model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=5, batch_size=64)

# Teacher 모델의 soft label 생성
temperature = 5.0  # Softmax temperature
teacher_logits = teacher_model.predict(x_train)
soft_labels = tf.nn.softmax(teacher_logits / temperature).numpy()

# Student 모델 정의 (간단한 모델)
student_model = Sequential([
    Flatten(input_shape=(28, 28, 1)),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Knowledge Distillation loss 함수 정의
def distillation_loss(y_true, y_pred, teacher_output, temperature):
    y_true_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
    soft_loss = tf.keras.losses.categorical_crossentropy(
        tf.nn.softmax(teacher_output / temperature),
        tf.nn.softmax(y_pred / temperature)
    )
    return y_true_loss + temperature**2 * soft_loss

# Student 모델 학습
optimizer = Adam(learning_rate=0.001)
for epoch in range(5):
    for i in range(0, len(x_train), 64):
        x_batch = x_train[i:i+64]
        y_batch = y_train[i:i+64]
        soft_batch = soft_labels[i:i+64]
        with tf.GradientTape() as tape:
            student_logits = student_model(x_batch, training=True)
            loss = distillation_loss(y_batch, student_logits, soft_batch, temperature)
        grads = tape.gradient(loss, student_model.trainable_variables)
        optimizer.apply_gradients(zip(grads, student_model.trainable_variables))

# Student 모델 평가
student_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
student_model.evaluate(x_test, y_test)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 35s 36ms/step - loss: 0.1311 - accuracy: 0.9603 - val_loss: 0.0481 - val_accuracy: 0.9848
# Epoch 2/5
# 938/938 [==============================] - 42s 45ms/step - loss: 0.0407 - accuracy: 0.9873 - val_loss: 0.0372 - val_accuracy: 0.9875
# Epoch 3/5
# 938/938 [==============================] - 38s 41ms/step - loss: 0.0280 - accuracy: 0.9911 - val_loss: 0.0287 - val_accuracy: 0.9895
# Epoch 4/5
# 938/938 [==============================] - 38s 40ms/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.0289 - val_accuracy: 0.9906
# Epoch 5/5
# 938/938 [==============================] - 38s 40ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.0247 - val_accuracy: 0.9928
# 1875/1875 [==============================] - 14s 7ms/step
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1170 - accuracy: 0.9641
# [0.11702550202608109, 0.9641000032424927]

# %% [markdown]
# ### GoogLeNet

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Flatten, Dense, Input, Dropout, concatenate
from tensorflow.keras.models import Model

# Inception Module 정의
def inception_module(x, f1, f3_in, f3, f5_in, f5, pool_proj):
    # 1x1 Conv
    conv1 = Conv2D(f1, (1, 1), padding='same', activation='relu')(x)

    # 1x1 Conv -> 3x3 Conv
    conv3 = Conv2D(f3_in, (1, 1), padding='same', activation='relu')(x)
    conv3 = Conv2D(f3, (3, 3), padding='same', activation='relu')(conv3)

    # 1x1 Conv -> 5x5 Conv
    conv5 = Conv2D(f5_in, (1, 1), padding='same', activation='relu')(x)
    conv5 = Conv2D(f5, (5, 5), padding='same', activation='relu')(conv5)

    # MaxPooling -> 1x1 Conv
    pool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    pool = Conv2D(pool_proj, (1, 1), padding='same', activation='relu')(pool)

    # Concat 모든 branch
    output = concatenate([conv1, conv3, conv5, pool], axis=-1)
    return output

# Auxiliary Classifier 정의
def auxiliary_classifier(x, num_classes):
    x = AveragePooling2D((5, 5), strides=(3, 3))(x)
    x = Conv2D(128, (1, 1), padding='same', activation='relu')(x)
    x = Flatten()(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.7)(x)
    x = Dense(num_classes, activation='softmax')(x)
    return x

# GoogLeNet 모델 정의
def googlenet(input_shape=(224, 224, 3), num_classes=1000):
    inputs = Input(shape=input_shape)

    # Stem Network
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu')(inputs)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = Conv2D(64, (1, 1), padding='same', activation='relu')(x)
    x = Conv2D(192, (3, 3), padding='same', activation='relu')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Inception Modules
    x = inception_module(x, 64, 96, 128, 16, 32, 32)
    x = inception_module(x, 128, 128, 192, 32, 96, 64)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    x = inception_module(x, 192, 96, 208, 16, 48, 64)
    aux1 = auxiliary_classifier(x, num_classes)  # Auxiliary Classifier 1

    x = inception_module(x, 160, 112, 224, 24, 64, 64)
    x = inception_module(x, 128, 128, 256, 24, 64, 64)
    x = inception_module(x, 112, 144, 288, 32, 64, 64)
    aux2 = auxiliary_classifier(x, num_classes)  # Auxiliary Classifier 2

    x = inception_module(x, 256, 160, 320, 32, 128, 128)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    x = inception_module(x, 256, 160, 320, 32, 128, 128)
    x = inception_module(x, 384, 192, 384, 48, 128, 128)

    # Final Output
    x = AveragePooling2D((7, 7), strides=(1, 1))(x)
    x = Flatten()(x)
    x = Dropout(0.4)(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    # 모델 정의 (Auxiliary Classifier 포함)
    model = Model(inputs, [outputs, aux1, aux2])
    return model

# GoogLeNet 모델 생성
model = googlenet(input_shape=(224, 224, 3), num_classes=10)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 192)  110784      ['conv2d_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 192)  0          ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 96)   18528       ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 28, 28, 16)   3088        ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 192)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 128)  110720      ['conv2d_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 28, 28, 32)   12832       ['conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 32)   6176        ['max_pooling2d_2[0][0]']
#
#  concatenate (Concatenate)      (None, 28, 28, 256)  0           ['conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 32)   8224        ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 256)  0          ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 192)  221376      ['conv2d_10[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 96)   76896       ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 64)   16448       ['max_pooling2d_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 28, 28, 480)  0           ['conv2d_9[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 480)  0          ['concatenate_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 96)   46176       ['max_pooling2d_4[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 16)   7696        ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 480)  0          ['max_pooling2d_4[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 192)  92352       ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 208)  179920      ['conv2d_16[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 48)   19248       ['conv2d_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 64)   30784       ['max_pooling2d_5[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 14, 14, 512)  0           ['conv2d_15[0][0]',
#                                                                   'conv2d_17[0][0]',
#                                                                   'conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 112)  57456       ['concatenate_2[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 24)   12312       ['concatenate_2[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 512)  0          ['concatenate_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 160)  82080       ['concatenate_2[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 224)  226016      ['conv2d_23[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 64)   38464       ['conv2d_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_6[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 14, 14, 512)  0           ['conv2d_22[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_26[0][0]',
#                                                                   'conv2d_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 128)  65664       ['concatenate_3[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 14, 14, 24)   12312       ['concatenate_3[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 512)  0          ['concatenate_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 128)  65664       ['concatenate_3[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 256)  295168      ['conv2d_29[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 14, 14, 64)   38464       ['conv2d_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_7[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 14, 14, 512)  0           ['conv2d_28[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_32[0][0]',
#                                                                   'conv2d_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 144)  73872       ['concatenate_4[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 32)   16416       ['concatenate_4[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 512)  0          ['concatenate_4[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 112)  57456       ['concatenate_4[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 288)  373536      ['conv2d_35[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 64)   51264       ['conv2d_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 64)   32832       ['max_pooling2d_8[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 14, 14, 528)  0           ['conv2d_34[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_38[0][0]',
#                                                                   'conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 160)  84640       ['concatenate_5[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 32)   16928       ['concatenate_5[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 14, 14, 528)  0          ['concatenate_5[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 256)  135424      ['concatenate_5[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 320)  461120      ['conv2d_42[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 14, 14, 128)  102528      ['conv2d_44[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 14, 14, 128)  67712       ['max_pooling2d_9[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 14, 14, 832)  0           ['conv2d_41[0][0]',
#                                                                   'conv2d_43[0][0]',
#                                                                   'conv2d_45[0][0]',
#                                                                   'conv2d_46[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 7, 7, 832)   0           ['concatenate_6[0][0]']
#  )
#
#  conv2d_48 (Conv2D)             (None, 7, 7, 160)    133280      ['max_pooling2d_10[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 7, 7, 32)     26656       ['max_pooling2d_10[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 7, 7, 832)   0           ['max_pooling2d_10[0][0]']
#  )
#
#  conv2d_47 (Conv2D)             (None, 7, 7, 256)    213248      ['max_pooling2d_10[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 7, 7, 320)    461120      ['conv2d_48[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 7, 7, 128)    102528      ['conv2d_50[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 7, 7, 128)    106624      ['max_pooling2d_11[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 7, 7, 832)    0           ['conv2d_47[0][0]',
#                                                                   'conv2d_49[0][0]',
#                                                                   'conv2d_51[0][0]',
#                                                                   'conv2d_52[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 7, 7, 192)    159936      ['concatenate_7[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 7, 7, 48)     39984       ['concatenate_7[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 7, 7, 832)   0           ['concatenate_7[0][0]']
#  )
#
#  conv2d_53 (Conv2D)             (None, 7, 7, 384)    319872      ['concatenate_7[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 7, 7, 384)    663936      ['conv2d_54[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 7, 7, 128)    153728      ['conv2d_56[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 7, 7, 128)    106624      ['max_pooling2d_12[0][0]']
#
#  average_pooling2d (AveragePool  (None, 4, 4, 512)   0           ['concatenate_2[0][0]']
#  ing2D)
#
#  average_pooling2d_1 (AveragePo  (None, 4, 4, 528)   0           ['concatenate_5[0][0]']
#  oling2D)
#
#  concatenate_8 (Concatenate)    (None, 7, 7, 1024)   0           ['conv2d_53[0][0]',
#                                                                   'conv2d_55[0][0]',
#                                                                   'conv2d_57[0][0]',
#                                                                   'conv2d_58[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 4, 4, 128)    65664       ['average_pooling2d[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 4, 4, 128)    67712       ['average_pooling2d_1[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 1, 1, 1024)  0           ['concatenate_8[0][0]']
#  oling2D)
#
#  flatten (Flatten)              (None, 2048)         0           ['conv2d_21[0][0]']
#
#  flatten_1 (Flatten)            (None, 2048)         0           ['conv2d_40[0][0]']
#
#  flatten_2 (Flatten)            (None, 1024)         0           ['average_pooling2d_2[0][0]']
#
#  dense (Dense)                  (None, 1024)         2098176     ['flatten[0][0]']
#
#  dense_2 (Dense)                (None, 1024)         2098176     ['flatten_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 1024)         0           ['flatten_2[0][0]']
#
#  dropout (Dropout)              (None, 1024)         0           ['dense[0][0]']
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 10)           10250       ['dropout_2[0][0]']
#
#  dense_1 (Dense)                (None, 10)           10250       ['dropout[0][0]']
#
#  dense_3 (Dense)                (None, 10)           10250       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 10,334,030
# Trainable params: 10,334,030
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Dense Block

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, ReLU, AveragePooling2D, GlobalAveragePooling2D, Dense, Input, concatenate
from tensorflow.keras.models import Model

# Dense Block 정의
def dense_block(x, num_layers, growth_rate):
    for _ in range(num_layers):
        # Bottleneck Layer: 1x1 Conv로 채널 수를 줄여 계산량 감소
        bn = BatchNormalization()(x)  # 입력 정규화
        relu = ReLU()(bn)  # 활성화 함수 적용
        conv = Conv2D(4 * growth_rate, (1, 1), padding='same', activation=None)(relu)  # 1x1 Convolution

        # 3x3 Convolution Layer
        bn = BatchNormalization()(conv)  # 정규화
        relu = ReLU()(bn)  # 활성화 함수 적용
        conv = Conv2D(growth_rate, (3, 3), padding='same', activation=None)(relu)  # 3x3 Convolution

        # Concatenate: 이전 레이어의 출력과 현재 레이어의 출력을 연결
        x = concatenate([x, conv], axis=-1)
    return x

# Transition Layer 정의
def transition_layer(x, reduction):
    # 채널 수 줄이기
    bn = BatchNormalization()(x)  # 정규화
    relu = ReLU()(bn)  # 활성화 함수 적용
    num_filters = int(x.shape[-1] * reduction)  # 채널 수 감소 비율 적용
    conv = Conv2D(num_filters, (1, 1), padding='same', activation=None)(relu)  # 1x1 Convolution

    # 공간 크기 줄이기
    pool = AveragePooling2D((2, 2), strides=2)(conv)  # 2x2 영역 평균 풀링
    return pool

# DenseNet 모델 정의
def densenet(input_shape=(224, 224, 3), num_classes=1000, growth_rate=32, num_blocks=4, num_layers_per_block=[6, 12, 24, 16]):
    inputs = Input(shape=input_shape)  # 입력 정의

    # 초기 Convolution Layer
    x = Conv2D(2 * growth_rate, (7, 7), strides=2, padding='same', activation=None)(inputs)  # 7x7 Conv
    x = BatchNormalization()(x)  # 정규화
    x = ReLU()(x)  # 활성화 함수
    x = AveragePooling2D((3, 3), strides=2, padding='same')(x)  # 3x3 Average Pooling

    # Dense Blocks and Transition Layers
    for i in range(num_blocks):
        x = dense_block(x, num_layers=num_layers_per_block[i], growth_rate=growth_rate)  # Dense Block 추가
        if i != num_blocks - 1:  # 마지막 블록 이후에는 Transition Layer 없음
            x = transition_layer(x, reduction=0.5)  # Transition Layer 추가

    # Global Average Pooling and Fully Connected Layer
    x = GlobalAveragePooling2D()(x)  # Feature 맵을 하나의 벡터로 변환
    outputs = Dense(num_classes, activation='softmax')(x)  # 클래스 예측

    # 모델 생성
    model = Model(inputs, outputs)
    return model

# DenseNet 모델 생성
model = densenet(input_shape=(224, 224, 3), num_classes=10, growth_rate=32)
model.summary()  # 모델 구조 출력
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_61 (Conv2D)             (None, 112, 112, 64  9472        ['input_2[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d_61[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 112, 112, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  average_pooling2d_3 (AveragePo  (None, 56, 56, 64)  0           ['re_lu[0][0]']
#  oling2D)
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['average_pooling2d_3[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 56, 56, 128)  8320        ['re_lu_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 128)  512        ['conv2d_62[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 56, 56, 128)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 56, 56, 32)   36896       ['re_lu_2[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 56, 56, 96)   0           ['average_pooling2d_3[0][0]',
#                                                                   'conv2d_63[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 96)  384         ['concatenate_9[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 56, 56, 96)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 56, 56, 128)  12416       ['re_lu_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 56, 56, 128)  512        ['conv2d_64[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 56, 56, 128)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 56, 56, 32)   36896       ['re_lu_4[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 56, 56, 128)  0           ['concatenate_9[0][0]',
#                                                                   'conv2d_65[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 56, 56, 128)  512        ['concatenate_10[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 56, 56, 128)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 56, 56, 128)  16512       ['re_lu_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 56, 56, 128)  512        ['conv2d_66[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 56, 56, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 56, 56, 32)   36896       ['re_lu_6[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 56, 56, 160)  0           ['concatenate_10[0][0]',
#                                                                   'conv2d_67[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 160)  640        ['concatenate_11[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 56, 56, 160)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 56, 56, 128)  20608       ['re_lu_7[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 56, 56, 128)  512        ['conv2d_68[0][0]']
#  rmalization)
#
#  re_lu_8 (ReLU)                 (None, 56, 56, 128)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 56, 56, 32)   36896       ['re_lu_8[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 56, 56, 192)  0           ['concatenate_11[0][0]',
#                                                                   'conv2d_69[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 56, 56, 192)  768        ['concatenate_12[0][0]']
#  rmalization)
#
#  re_lu_9 (ReLU)                 (None, 56, 56, 192)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 56, 56, 128)  24704       ['re_lu_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 56, 56, 128)  512        ['conv2d_70[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 56, 56, 128)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 56, 56, 32)   36896       ['re_lu_10[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 56, 56, 224)  0           ['concatenate_12[0][0]',
#                                                                   'conv2d_71[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 56, 56, 224)  896        ['concatenate_13[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 56, 56, 224)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 56, 56, 128)  28800       ['re_lu_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 56, 56, 128)  512        ['conv2d_72[0][0]']
#  ormalization)
#
#  re_lu_12 (ReLU)                (None, 56, 56, 128)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 56, 56, 32)   36896       ['re_lu_12[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 56, 56, 256)  0           ['concatenate_13[0][0]',
#                                                                   'conv2d_73[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 56, 56, 256)  1024       ['concatenate_14[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 56, 56, 256)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 56, 56, 128)  32896       ['re_lu_13[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 28, 28, 128)  0          ['conv2d_74[0][0]']
#  oling2D)
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 128)  512        ['average_pooling2d_4[0][0]']
#  ormalization)
#
#  re_lu_14 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 28, 28, 128)  16512       ['re_lu_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 128)  512        ['conv2d_75[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_15[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 28, 28, 160)  0           ['average_pooling2d_4[0][0]',
#                                                                   'conv2d_76[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 28, 28, 160)  640        ['concatenate_15[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 28, 28, 160)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 28, 28, 128)  20608       ['re_lu_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 128)  512        ['conv2d_77[0][0]']
#  ormalization)
#
#  re_lu_17 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_17[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 28, 28, 192)  0           ['concatenate_15[0][0]',
#                                                                   'conv2d_78[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 192)  768        ['concatenate_16[0][0]']
#  ormalization)
#
#  re_lu_18 (ReLU)                (None, 28, 28, 192)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 28, 28, 128)  24704       ['re_lu_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 128)  512        ['conv2d_79[0][0]']
#  ormalization)
#
#  re_lu_19 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_19[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 28, 28, 224)  0           ['concatenate_16[0][0]',
#                                                                   'conv2d_80[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 28, 28, 224)  896        ['concatenate_17[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 28, 28, 224)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 28, 28, 128)  28800       ['re_lu_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 28, 28, 128)  512        ['conv2d_81[0][0]']
#  ormalization)
#
#  re_lu_21 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_21[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 28, 28, 256)  0           ['concatenate_17[0][0]',
#                                                                   'conv2d_82[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 28, 28, 256)  1024       ['concatenate_18[0][0]']
#  ormalization)
#
#  re_lu_22 (ReLU)                (None, 28, 28, 256)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 28, 28, 128)  32896       ['re_lu_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 28, 28, 128)  512        ['conv2d_83[0][0]']
#  ormalization)
#
#  re_lu_23 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_23[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 28, 28, 288)  0           ['concatenate_18[0][0]',
#                                                                   'conv2d_84[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 28, 28, 288)  1152       ['concatenate_19[0][0]']
#  ormalization)
#
#  re_lu_24 (ReLU)                (None, 28, 28, 288)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 28, 28, 128)  36992       ['re_lu_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 28, 28, 128)  512        ['conv2d_85[0][0]']
#  ormalization)
#
#  re_lu_25 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_25[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 28, 28, 320)  0           ['concatenate_19[0][0]',
#                                                                   'conv2d_86[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 28, 28, 320)  1280       ['concatenate_20[0][0]']
#  ormalization)
#
#  re_lu_26 (ReLU)                (None, 28, 28, 320)  0           ['batch_normalization_26[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 28, 28, 128)  41088       ['re_lu_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 28, 28, 128)  512        ['conv2d_87[0][0]']
#  ormalization)
#
#  re_lu_27 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_27[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 28, 28, 352)  0           ['concatenate_20[0][0]',
#                                                                   'conv2d_88[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 28, 28, 352)  1408       ['concatenate_21[0][0]']
#  ormalization)
#
#  re_lu_28 (ReLU)                (None, 28, 28, 352)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 28, 28, 128)  45184       ['re_lu_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 28, 28, 128)  512        ['conv2d_89[0][0]']
#  ormalization)
#
#  re_lu_29 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_29[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 28, 28, 384)  0           ['concatenate_21[0][0]',
#                                                                   'conv2d_90[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 28, 28, 384)  1536       ['concatenate_22[0][0]']
#  ormalization)
#
#  re_lu_30 (ReLU)                (None, 28, 28, 384)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 28, 28, 128)  49280       ['re_lu_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 28, 28, 128)  512        ['conv2d_91[0][0]']
#  ormalization)
#
#  re_lu_31 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_31[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 28, 28, 416)  0           ['concatenate_22[0][0]',
#                                                                   'conv2d_92[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 28, 28, 416)  1664       ['concatenate_23[0][0]']
#  ormalization)
#
#  re_lu_32 (ReLU)                (None, 28, 28, 416)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 28, 28, 128)  53376       ['re_lu_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 28, 28, 128)  512        ['conv2d_93[0][0]']
#  ormalization)
#
#  re_lu_33 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_33[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 28, 28, 448)  0           ['concatenate_23[0][0]',
#                                                                   'conv2d_94[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 28, 28, 448)  1792       ['concatenate_24[0][0]']
#  ormalization)
#
#  re_lu_34 (ReLU)                (None, 28, 28, 448)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 28, 28, 128)  57472       ['re_lu_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 28, 28, 128)  512        ['conv2d_95[0][0]']
#  ormalization)
#
#  re_lu_35 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_35[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 28, 28, 480)  0           ['concatenate_24[0][0]',
#                                                                   'conv2d_96[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 28, 28, 480)  1920       ['concatenate_25[0][0]']
#  ormalization)
#
#  re_lu_36 (ReLU)                (None, 28, 28, 480)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 28, 28, 128)  61568       ['re_lu_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 28, 28, 128)  512        ['conv2d_97[0][0]']
#  ormalization)
#
#  re_lu_37 (ReLU)                (None, 28, 28, 128)  0           ['batch_normalization_37[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 28, 28, 32)   36896       ['re_lu_37[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 28, 28, 512)  0           ['concatenate_25[0][0]',
#                                                                   'conv2d_98[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 28, 28, 512)  2048       ['concatenate_26[0][0]']
#  ormalization)
#
#  re_lu_38 (ReLU)                (None, 28, 28, 512)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 28, 28, 256)  131328      ['re_lu_38[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 14, 14, 256)  0          ['conv2d_99[0][0]']
#  oling2D)
#
#  batch_normalization_39 (BatchN  (None, 14, 14, 256)  1024       ['average_pooling2d_5[0][0]']
#  ormalization)
#
#  re_lu_39 (ReLU)                (None, 14, 14, 256)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 14, 14, 128)  32896       ['re_lu_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 14, 14, 128)  512        ['conv2d_100[0][0]']
#  ormalization)
#
#  re_lu_40 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_40[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 14, 14, 288)  0           ['average_pooling2d_5[0][0]',
#                                                                   'conv2d_101[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 14, 14, 288)  1152       ['concatenate_27[0][0]']
#  ormalization)
#
#  re_lu_41 (ReLU)                (None, 14, 14, 288)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 14, 14, 128)  36992       ['re_lu_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 14, 14, 128)  512        ['conv2d_102[0][0]']
#  ormalization)
#
#  re_lu_42 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_42[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 14, 14, 320)  0           ['concatenate_27[0][0]',
#                                                                   'conv2d_103[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 14, 14, 320)  1280       ['concatenate_28[0][0]']
#  ormalization)
#
#  re_lu_43 (ReLU)                (None, 14, 14, 320)  0           ['batch_normalization_43[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 14, 14, 128)  41088       ['re_lu_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 14, 14, 128)  512        ['conv2d_104[0][0]']
#  ormalization)
#
#  re_lu_44 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_44[0][0]']
#
#  concatenate_29 (Concatenate)   (None, 14, 14, 352)  0           ['concatenate_28[0][0]',
#                                                                   'conv2d_105[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 14, 14, 352)  1408       ['concatenate_29[0][0]']
#  ormalization)
#
#  re_lu_45 (ReLU)                (None, 14, 14, 352)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 14, 14, 128)  45184       ['re_lu_45[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 14, 14, 128)  512        ['conv2d_106[0][0]']
#  ormalization)
#
#  re_lu_46 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_46[0][0]']
#
#  concatenate_30 (Concatenate)   (None, 14, 14, 384)  0           ['concatenate_29[0][0]',
#                                                                   'conv2d_107[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 14, 14, 384)  1536       ['concatenate_30[0][0]']
#  ormalization)
#
#  re_lu_47 (ReLU)                (None, 14, 14, 384)  0           ['batch_normalization_47[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 14, 14, 128)  49280       ['re_lu_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 14, 14, 128)  512        ['conv2d_108[0][0]']
#  ormalization)
#
#  re_lu_48 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_48[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 14, 14, 416)  0           ['concatenate_30[0][0]',
#                                                                   'conv2d_109[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 14, 14, 416)  1664       ['concatenate_31[0][0]']
#  ormalization)
#
#  re_lu_49 (ReLU)                (None, 14, 14, 416)  0           ['batch_normalization_49[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 14, 14, 128)  53376       ['re_lu_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 14, 14, 128)  512        ['conv2d_110[0][0]']
#  ormalization)
#
#  re_lu_50 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_50[0][0]']
#
#  concatenate_32 (Concatenate)   (None, 14, 14, 448)  0           ['concatenate_31[0][0]',
#                                                                   'conv2d_111[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 14, 14, 448)  1792       ['concatenate_32[0][0]']
#  ormalization)
#
#  re_lu_51 (ReLU)                (None, 14, 14, 448)  0           ['batch_normalization_51[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 14, 14, 128)  57472       ['re_lu_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 14, 14, 128)  512        ['conv2d_112[0][0]']
#  ormalization)
#
#  re_lu_52 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_52[0][0]']
#
#  concatenate_33 (Concatenate)   (None, 14, 14, 480)  0           ['concatenate_32[0][0]',
#                                                                   'conv2d_113[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 14, 14, 480)  1920       ['concatenate_33[0][0]']
#  ormalization)
#
#  re_lu_53 (ReLU)                (None, 14, 14, 480)  0           ['batch_normalization_53[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 14, 14, 128)  61568       ['re_lu_53[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 14, 14, 128)  512        ['conv2d_114[0][0]']
#  ormalization)
#
#  re_lu_54 (ReLU)                (None, 14, 14, 128)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 14, 14, 32)   36896       ['re_lu_54[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 14, 14, 512)  0           ['concatenate_33[0][0]',
#                                                                   'conv2d_115[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 14, 14, 512)  2048       ['concatenate_34[0][0]']
#  ormalization)
#
#  re_lu_55 (ReLU)                (None, 14, 14, 512)  0           ['batch_normalization_55[0][0]']
# ...
#  Normalization)
#
#  re_lu_102 (ReLU)               (None, 7, 7, 736)    0           ['batch_normalization_102[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 7, 7, 128)    94336       ['re_lu_102[0][0]']
#
#  batch_normalization_103 (Batch  (None, 7, 7, 128)   512         ['conv2d_163[0][0]']
#  Normalization)
#
#  re_lu_103 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_103[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_103[0][0]']
#
#  concatenate_58 (Concatenate)   (None, 7, 7, 768)    0           ['concatenate_57[0][0]',
#                                                                   'conv2d_164[0][0]']
#
#  batch_normalization_104 (Batch  (None, 7, 7, 768)   3072        ['concatenate_58[0][0]']
#  Normalization)
#
#  re_lu_104 (ReLU)               (None, 7, 7, 768)    0           ['batch_normalization_104[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 7, 7, 128)    98432       ['re_lu_104[0][0]']
#
#  batch_normalization_105 (Batch  (None, 7, 7, 128)   512         ['conv2d_165[0][0]']
#  Normalization)
#
#  re_lu_105 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_105[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_105[0][0]']
#
#  concatenate_59 (Concatenate)   (None, 7, 7, 800)    0           ['concatenate_58[0][0]',
#                                                                   'conv2d_166[0][0]']
#
#  batch_normalization_106 (Batch  (None, 7, 7, 800)   3200        ['concatenate_59[0][0]']
#  Normalization)
#
#  re_lu_106 (ReLU)               (None, 7, 7, 800)    0           ['batch_normalization_106[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 7, 7, 128)    102528      ['re_lu_106[0][0]']
#
#  batch_normalization_107 (Batch  (None, 7, 7, 128)   512         ['conv2d_167[0][0]']
#  Normalization)
#
#  re_lu_107 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_107[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_107[0][0]']
#
#  concatenate_60 (Concatenate)   (None, 7, 7, 832)    0           ['concatenate_59[0][0]',
#                                                                   'conv2d_168[0][0]']
#
#  batch_normalization_108 (Batch  (None, 7, 7, 832)   3328        ['concatenate_60[0][0]']
#  Normalization)
#
#  re_lu_108 (ReLU)               (None, 7, 7, 832)    0           ['batch_normalization_108[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 7, 7, 128)    106624      ['re_lu_108[0][0]']
#
#  batch_normalization_109 (Batch  (None, 7, 7, 128)   512         ['conv2d_169[0][0]']
#  Normalization)
#
#  re_lu_109 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_109[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_109[0][0]']
#
#  concatenate_61 (Concatenate)   (None, 7, 7, 864)    0           ['concatenate_60[0][0]',
#                                                                   'conv2d_170[0][0]']
#
#  batch_normalization_110 (Batch  (None, 7, 7, 864)   3456        ['concatenate_61[0][0]']
#  Normalization)
#
#  re_lu_110 (ReLU)               (None, 7, 7, 864)    0           ['batch_normalization_110[0][0]']
#
#  conv2d_171 (Conv2D)            (None, 7, 7, 128)    110720      ['re_lu_110[0][0]']
#
#  batch_normalization_111 (Batch  (None, 7, 7, 128)   512         ['conv2d_171[0][0]']
#  Normalization)
#
#  re_lu_111 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_111[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_111[0][0]']
#
#  concatenate_62 (Concatenate)   (None, 7, 7, 896)    0           ['concatenate_61[0][0]',
#                                                                   'conv2d_172[0][0]']
#
#  batch_normalization_112 (Batch  (None, 7, 7, 896)   3584        ['concatenate_62[0][0]']
#  Normalization)
#
#  re_lu_112 (ReLU)               (None, 7, 7, 896)    0           ['batch_normalization_112[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 7, 7, 128)    114816      ['re_lu_112[0][0]']
#
#  batch_normalization_113 (Batch  (None, 7, 7, 128)   512         ['conv2d_173[0][0]']
#  Normalization)
#
#  re_lu_113 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_113[0][0]']
#
#  conv2d_174 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_113[0][0]']
#
#  concatenate_63 (Concatenate)   (None, 7, 7, 928)    0           ['concatenate_62[0][0]',
#                                                                   'conv2d_174[0][0]']
#
#  batch_normalization_114 (Batch  (None, 7, 7, 928)   3712        ['concatenate_63[0][0]']
#  Normalization)
#
#  re_lu_114 (ReLU)               (None, 7, 7, 928)    0           ['batch_normalization_114[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 7, 7, 128)    118912      ['re_lu_114[0][0]']
#
#  batch_normalization_115 (Batch  (None, 7, 7, 128)   512         ['conv2d_175[0][0]']
#  Normalization)
#
#  re_lu_115 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_115[0][0]']
#
#  conv2d_176 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_115[0][0]']
#
#  concatenate_64 (Concatenate)   (None, 7, 7, 960)    0           ['concatenate_63[0][0]',
#                                                                   'conv2d_176[0][0]']
#
#  batch_normalization_116 (Batch  (None, 7, 7, 960)   3840        ['concatenate_64[0][0]']
#  Normalization)
#
#  re_lu_116 (ReLU)               (None, 7, 7, 960)    0           ['batch_normalization_116[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 7, 7, 128)    123008      ['re_lu_116[0][0]']
#
#  batch_normalization_117 (Batch  (None, 7, 7, 128)   512         ['conv2d_177[0][0]']
#  Normalization)
#
#  re_lu_117 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_117[0][0]']
#
#  conv2d_178 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_117[0][0]']
#
#  concatenate_65 (Concatenate)   (None, 7, 7, 992)    0           ['concatenate_64[0][0]',
#                                                                   'conv2d_178[0][0]']
#
#  batch_normalization_118 (Batch  (None, 7, 7, 992)   3968        ['concatenate_65[0][0]']
#  Normalization)
#
#  re_lu_118 (ReLU)               (None, 7, 7, 992)    0           ['batch_normalization_118[0][0]']
#
#  conv2d_179 (Conv2D)            (None, 7, 7, 128)    127104      ['re_lu_118[0][0]']
#
#  batch_normalization_119 (Batch  (None, 7, 7, 128)   512         ['conv2d_179[0][0]']
#  Normalization)
#
#  re_lu_119 (ReLU)               (None, 7, 7, 128)    0           ['batch_normalization_119[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 7, 7, 32)     36896       ['re_lu_119[0][0]']
#
#  concatenate_66 (Concatenate)   (None, 7, 7, 1024)   0           ['concatenate_65[0][0]',
#                                                                   'conv2d_180[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['concatenate_66[0][0]']
#  alAveragePooling2D)
#
#  dense_9 (Dense)                (None, 10)           10250       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 7,053,898
# Trainable params: 6,972,298
# Non-trainable params: 81,600
# __________________________________________________________________________________________________

# %% [markdown]
# ### SENet

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, GlobalAveragePooling2D, Dense, Reshape, Multiply, Input
from tensorflow.keras.models import Model

# Squeeze-and-Excitation Block 정의
def se_block(input_tensor, reduction=16):
    """
    Squeeze-and-Excitation Block
    Args:
        input_tensor: 입력 텐서
        reduction: 채널 축소 비율
    Returns:
        output_tensor: SE Block이 적용된 텐서
    """
    # 채널 수 가져오기
    channels = input_tensor.shape[-1]

    # Squeeze: Global Average Pooling
    squeeze = GlobalAveragePooling2D()(input_tensor)

    # Excitation: Fully Connected 레이어
    excitation = Dense(channels // reduction, activation='relu')(squeeze)  # 축소 단계
    excitation = Dense(channels, activation='sigmoid')(excitation)  # 복원 단계

    # Excitation 값을 채널 차원에 맞게 Reshape
    excitation = Reshape((1, 1, channels))(excitation)

    # 입력 텐서와 Excitation 값을 곱하여 조정
    output_tensor = Multiply()([input_tensor, excitation])
    return output_tensor

# 간단한 CNN 모델에 SE Block 추가
def create_se_cnn(input_shape=(224, 224, 3), num_classes=10):
    inputs = Input(shape=input_shape)

    # Convolution Layer
    x = Conv2D(64, (3, 3), padding='same', activation='relu')(inputs)

    # SE Block 적용
    x = se_block(x)

    # 추가 Convolution Layer
    x = Conv2D(128, (3, 3), padding='same', activation='relu')(x)

    # SE Block 적용
    x = se_block(x)

    # Global Average Pooling과 출력
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    # 모델 생성
    model = Model(inputs, outputs)
    return model

# 모델 생성
model = create_se_cnn(input_shape=(224, 224, 3), num_classes=10)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_181 (Conv2D)            (None, 224, 224, 64  1792        ['input_3[0][0]']
#                                 )
#
#  global_average_pooling2d_1 (Gl  (None, 64)          0           ['conv2d_181[0][0]']
#  obalAveragePooling2D)
#
#  dense_10 (Dense)               (None, 4)            260         ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  dense_11 (Dense)               (None, 64)           320         ['dense_10[0][0]']
#
#  reshape (Reshape)              (None, 1, 1, 64)     0           ['dense_11[0][0]']
#
#  multiply (Multiply)            (None, 224, 224, 64  0           ['conv2d_181[0][0]',
#                                 )                                 'reshape[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 224, 224, 12  73856       ['multiply[0][0]']
#                                 8)
#
#  global_average_pooling2d_2 (Gl  (None, 128)         0           ['conv2d_182[0][0]']
#  obalAveragePooling2D)
#
#  dense_12 (Dense)               (None, 8)            1032        ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  dense_13 (Dense)               (None, 128)          1152        ['dense_12[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 1, 128)    0           ['dense_13[0][0]']
#
#  multiply_1 (Multiply)          (None, 224, 224, 12  0           ['conv2d_182[0][0]',
#                                 8)                                'reshape_1[0][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 128)         0           ['multiply_1[0][0]']
#  obalAveragePooling2D)
#
#  dense_14 (Dense)               (None, 10)           1290        ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 79,702
# Trainable params: 79,702
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### EfficientNet

# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input
from tensorflow.keras.models import Model

# EfficientNet 기반 모델 정의
def create_efficientnet(input_shape=(224, 224, 3), num_classes=10):
    """
    EfficientNet 기반 모델 생성
    Args:
        input_shape: 입력 이미지 크기 (Height, Width, Channels)
        num_classes: 출력 클래스 수
    Returns:
        model: EfficientNet 기반 모델
    """

    
    # *** EfficientNetB0 사전 학습된 모델 로드 (ImageNet 가중치 사용)
    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=input_shape)

    # Feature Extraction (기본 모델 출력 가져오기)
    x = base_model.output
    x = GlobalAveragePooling2D()(x)  # Feature 맵을 벡터로 변환

    # Fully Connected Layer 추가
    outputs = Dense(num_classes, activation='softmax')(x)

    # 전체 모델 생성
    model = Model(inputs=base_model.input, outputs=outputs)

    # *** 사전 학습된 레이어 고정 (Fine-tuning 시 고정 해제 가능)
    for layer in base_model.layers:
        layer.trainable = False

    return model

# 모델 생성
model = create_efficientnet(input_shape=(224, 224, 3), num_classes=10)

# 모델 컴파일
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# 모델 구조 출력
model.summary()

# 데이터 준비 (CIFAR-10 예제)
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = tf.image.resize(x_train / 255.0, (224, 224))  # EfficientNet 입력 크기로 리사이즈
x_test = tf.image.resize(x_test / 255.0, (224, 224))
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# 모델 학습
model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=5, batch_size=32)
